# %% [markdown]
# <a href="https://colab.research.google.com/github/ChitviJoshi/Assignment-4/blob/main/Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile Q1.cpp
# #include <iostream>
# using namespace std;
#
# #define MAX 100   // Maximum size of queue
#
# class Queue {
#     int A[MAX];
#     int front, rear;
#
# public:
#     Queue() {
#         front = -1;
#         rear = -1;
#     }
#
#     bool isEmpty() {
#         return (front == -1 && rear == -1);
#     }
#
#     bool isFull() {
#         return (rear == MAX - 1);
#     }
#
#     void enqueue(int x) {
#         if (isFull()) {
#             cout << "Queue Overflow!" << endl;
#             return;
#         }
#         if (isEmpty()) {
#             front = rear = 0;
#         } else {
#             rear++;
#         }
#         A[rear] = x;
#         cout << x << " inserted into queue." << endl;
#     }
#
#     void dequeue() {
#         if (isEmpty()) {
#             cout << "Queue Underflow!" << endl;
#             return;
#         }
#         cout << A[front] << " removed from queue." << endl;
#         if (front == rear) {
#             front = rear = -1;
#         } else {
#             front++;
#         }
#     }
#
#     void peek() {
#         if (isEmpty()) {
#             cout << "Queue is empty!" << endl;
#         } else {
#             cout << "Front element: " << A[front] << endl;
#         }
#     }
#
#     void display() {
#         if (isEmpty()) {
#             cout << "Queue is empty!" << endl;
#             return;
#         }
#         cout << "Queue elements: ";
#         for (int i = front; i <= rear; i++) {
#             cout << A[i] << " ";
#         }
#         cout << endl;
#     }
# };
#
# int main() {
#     Queue q;
#     int chc, val;
#
#     do {
#         cout << "Queue Menu " << endl;
#         cout << "1. Enqueue\n2. Dequeue\n3. Peek\n4. Display\n5. Exit" << endl;
#         cout << "Enter your chc: ";
#         cin >> chc;
#
#         switch (chc) {
#         case 1:
#             cout << "Enter value to insert: ";
#             cin >> val;
#             q.enqueue(val);
#             break;
#         case 2:
#             q.dequeue();
#             break;
#         case 3:
#             q.peek();
#             break;
#         case 4:
#             q.display();
#             break;
#         case 5:
#             cout << "Exiting program..." << endl;
#             break;
#         default:
#             cout << "Invalid chc!" << endl;
#         }
#     } while (chc != 5);
#
#     return 0;
# }
# Out:
# Overwriting Q1.cpp

# %%
# !g++ Q1.cpp -o Q1
# !./Q1
# Out:
# Queue Menu
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. Display
# 5. Exit
# Enter your chc: 1
# Enter value to insert: 6
# 6 inserted into queue.
# Queue Menu
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. Display
# 5. Exit
# Enter your chc: 1
# Enter value to insert: 8
# 8 inserted into queue.
# Queue Menu
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. Display
# 5. Exit
# Enter your chc: 1
# Enter value to insert: 1
# 1 inserted into queue.
# Queue Menu
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. Display
# 5. Exit
# Enter your chc: 3
# Front element: 6
# Queue Menu
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. Display
# 5. Exit
# Enter your chc: 2
# 6 removed from queue.
# Queue Menu
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. Display
# 5. Exit
# Enter your chc: 4
# Queue elements: 8 1
# Queue Menu
# 1. Enqueue
# 2. Dequeue
# 3. Peek
# 4. Display
# 5. Exit
# Enter your chc: 5
# Exiting program...
